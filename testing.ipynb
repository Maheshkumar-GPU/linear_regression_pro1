# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheshkumar-GPU/linear_regression_pro1/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# go to your repo folder (change if needed)
cd REPO_NAME || exit 1

# create a test file
echo 'print("Hello, saved from Google Colab!")' > test_colab.py

# git workflow
git add test_colab.py
git commit -m "Test saving code from Colab"
git push
# Out:
#   File "/tmp/ipython-input-3814179754.py", line 2
#     cd REPO_NAME || exit 1
#        ^
# SyntaxError: invalid syntax
